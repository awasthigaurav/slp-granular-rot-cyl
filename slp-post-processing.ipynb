# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit

# %% [markdown]
# ### shear rate = 0.1

# %%
intf = pd.read_csv('intf0-1.dat',header=None,sep='\s')
intf = intf.set_axis(['x','ymin','ymax'],axis=1)
intf
# Out:
# <ipython-input-41-9eee5bf6df97>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   intf = pd.read_csv('intf0-1.dat',header=None,sep='\s')
#        x      ymin      ymax
# 0  -4.95 -0.578177  0.000000
# 1  -4.85 -0.738898 -0.501378
# 2  -4.75 -0.848555 -0.439020
# 3  -4.65 -0.917424 -0.417173
# 4  -4.55 -0.983886 -0.385696
# ..   ...       ...       ...
# 95  4.55 -0.796031 -0.300951
# 96  4.65 -0.734841 -0.309960
# 97  4.75 -0.660265 -0.319795
# 98  4.85 -0.581036 -0.337144
# 99  4.95 -0.443200 -0.444990
#
# [100 rows x 3 columns]

# %%
x = intf['x']
x = x[1:-1]
ymin = intf['ymin']
ymin = ymin[1:-1]
ymax = intf['ymax']
ymax = ymax[1:-1]

# %%
plt.plot(x,ymin,marker='.')
plt.plot(x,ymax,marker='.')
delta = np.min(ymin-ymax)*np.sqrt(1-(x**2)/25)
plt.plot(x,delta)
plt.plot(x,ymin-ymax,marker='.')
plt.legend(['ymin','ymax','function','ymin-ymax'])
plt.title('Shear rate = 0.1')
plt.ylabel('y')
plt.xlabel('x')
print(r2_score(delta,ymin-ymax))
# Out:
# 0.981485369864745

# %% [markdown]
# ### shear rate = 0.3

# %%
intf = pd.read_csv('intf0-3.dat',header=None,sep='\s')
intf = intf.set_axis(['x','ymin','ymax'],axis=1)
intf
# Out:
# <ipython-input-44-1c11141c3a4b>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   intf = pd.read_csv('intf0-3.dat',header=None,sep='\s')
#        x      ymin      ymax
# 0  -4.95 -0.403428  0.000000
# 1  -4.85 -0.645872 -0.236746
# 2  -4.75 -0.730297 -0.146558
# 3  -4.65 -0.801873 -0.107553
# 4  -4.55 -0.861590 -0.053306
# ..   ...       ...       ...
# 95  4.55 -0.903496 -0.236790
# 96  4.65 -0.816676 -0.226651
# 97  4.75 -0.715446 -0.222187
# 98  4.85 -0.589046 -0.239280
# 99  4.95 -0.387989  0.000000
#
# [100 rows x 3 columns]

# %%
x = intf['x']
x = x[1:-1]
ymin = intf['ymin']
ymin = ymin[1:-1]
ymax = intf['ymax']
ymax = ymax[1:-1]

# %%
plt.plot(x,ymin,marker='.')
plt.plot(x,ymax,marker='.')
delta = np.min(ymin-ymax)*np.sqrt(1-(x**2)/25)
plt.plot(x,delta)
plt.plot(x,ymin-ymax,marker='.')
plt.legend(['ymin','ymax','function','ymin-ymax'])
plt.title('Shear rate = 0.3')
plt.ylabel('y')
plt.xlabel('x')
print(r2_score(delta,ymin-ymax))
# Out:
# 0.9101640063902364

# %% [markdown]
# ### shear rate = 0.05

# %%
intf = pd.read_csv('intf0-05.dat',header=None,sep='\s')
intf = intf.set_axis(['x','ymin','ymax'],axis=1)
intf
# Out:
# <ipython-input-57-5420639be6ce>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   intf = pd.read_csv('intf0-05.dat',header=None,sep='\s')
#        x      ymin      ymax
# 0  -4.95 -0.635338  0.000000
# 1  -4.85 -0.810322 -0.593398
# 2  -4.75 -0.956025 -0.534221
# 3  -4.65 -1.001066 -0.508012
# 4  -4.55 -1.027075 -0.472472
# ..   ...       ...       ...
# 95  4.55 -0.749611 -0.288635
# 96  4.65 -0.690639 -0.298155
# 97  4.75 -0.633604 -0.311265
# 98  4.85 -0.541868 -0.333619
# 99  4.95 -0.439077 -0.410229
#
# [100 rows x 3 columns]

# %%
x = intf['x']
x = x[1:-1]
ymin = intf['ymin']
ymin = ymin[1:-1]
ymax = intf['ymax']
ymax = ymax[1:-1]

# %%
plt.plot(x,ymin,marker='.')
plt.plot(x,ymax,marker='.')
delta = np.min(ymin-ymax)*np.sqrt(1-(x**2)/25)
plt.plot(x,delta)
plt.plot(x,ymin-ymax,marker='.')
plt.legend(['ymin','ymax','function','ymin-ymax'])
plt.title('Shear rate = 0.05')
plt.ylabel('y')
plt.xlabel('x')
print(r2_score(delta,ymin-ymax))
# Out:
# 0.9795861939294923

# %% [markdown]
# ### shear rate = 0.025

# %%
intf = pd.read_csv('intf0-025.dat',header=None,sep='\s')
intf = intf.set_axis(['x','ymin','ymax'],axis=1)
intf
# Out:
# <ipython-input-50-7575e112dc6e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   intf = pd.read_csv('intf0-025.dat',header=None,sep='\s')
#        x      ymin      ymax
# 0  -4.95 -0.715790  0.000000
# 1  -4.85 -0.883737 -0.678069
# 2  -4.75 -0.963340 -0.626455
# 3  -4.65 -1.036925 -0.604202
# 4  -4.55 -1.078795 -0.574660
# ..   ...       ...       ...
# 95  4.55 -0.707049 -0.231680
# 96  4.65 -0.643339 -0.235615
# 97  4.75 -0.584992 -0.251171
# 98  4.85 -0.490271 -0.299846
# 99  4.95 -0.408237 -0.334335
#
# [100 rows x 3 columns]

# %%
x = intf['x']
x = x[1:-1]
ymin = intf['ymin']
ymin = ymin[1:-1]
ymax = intf['ymax']
ymax = ymax[1:-1]

# %%
plt.plot(x,ymin,marker='.')
plt.plot(x,ymax,marker='.')
delta = np.min(ymin-ymax)*np.sqrt(1-(x**2)/25)
plt.plot(x,delta)
plt.plot(x,ymin-ymax,marker='.')
plt.legend(['ymin','ymax','function','ymin-ymax'])
plt.title('Shear rate = 0.025')
plt.ylabel('y')
plt.xlabel('x')
print(r2_score(delta,ymin-ymax))
# Out:
# 0.9858033445508897

# %%
np.min(ymin-ymax)
# Out:
# -1.190955

# %% [markdown]
# ### shear rate = 0.0125

# %%
intf = pd.read_csv('intf0-0125.dat',header=None,sep='\s')
intf = intf.set_axis(['x','ymin','ymax'],axis=1)
intf
# Out:
# <ipython-input-54-4d0203276ae0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   intf = pd.read_csv('intf0-0125.dat',header=None,sep='\s')
#        x      ymin      ymax
# 0  -4.95 -0.683222  0.000000
# 1  -4.85 -0.808888 -0.616197
# 2  -4.75 -0.928852 -0.557820
# 3  -4.65 -1.002607 -0.516685
# 4  -4.55 -1.026932 -0.508186
# ..   ...       ...       ...
# 95  4.55 -0.694155 -0.224581
# 96  4.65 -0.640796 -0.227544
# 97  4.75 -0.590436 -0.232542
# 98  4.85 -0.506632 -0.260693
# 99  4.95 -0.365614 -0.321947
#
# [100 rows x 3 columns]

# %%
x = intf['x']
x = x[1:-1]
ymin = intf['ymin']
ymin = ymin[1:-1]
ymax = intf['ymax']
ymax = ymax[1:-1]

# %%
plt.plot(x,ymin,marker='.')
plt.plot(x,ymax,marker='.')
delta = np.min(ymin-ymax)*np.sqrt(1-(x**2)/25)
plt.plot(x,delta)
plt.plot(x,ymin-ymax,marker='.')
plt.legend(['ymin','ymax','function','ymin-ymax'])
plt.title('Shear rate = 0.0125')
plt.ylabel('y')
plt.xlabel('x')
print(r2_score(delta,ymin-ymax))
# Out:
# 0.9817632819121079

# %% [markdown]
# ## Omega vs r and omega vs theta in a 60 degree slice of the cylinder

# %%
df = pd.read_csv('avv.dat',header=None,sep='\s')
df.columns = ['x','y','phi','vx','vy','r','omega','theta','vtheta','y-ymin','ymax']
df['theta']*=180/np.pi
df = df[df['r']<5]
df
# Out:
# <ipython-input-33-cf1870743fc2>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('avv.dat',header=None,sep='\s')
#          x     y       phi        vx        vy         r     omega  \
# 43   -4.95 -0.65  0.009031  0.011613  0.073282  4.992494 -0.014251
# 44   -4.95 -0.55  0.000000  0.000000  0.000000  4.980462  0.000000
# 45   -4.95 -0.45  0.000000  0.000000  0.000000  4.970412  0.000000
# 46   -4.95 -0.35  0.000000  0.000000  0.000000  4.962358  0.000000
# 47   -4.95 -0.25  0.000000  0.000000  0.000000  4.956309  0.000000
# ...    ...   ...       ...       ...       ...       ...       ...
# 9952  4.95  0.25  0.000000  0.000000  0.000000  4.956309  0.000000
# 9953  4.95  0.35  0.000000  0.000000  0.000000  4.962358  0.000000
# ...

# %%
df1 = df.loc[(df['theta']>-120) & (df['theta']<-60)]
df1['theta']+=90
df1 = df1[df1['y-ymin']<0]
df1
# Out:
# <ipython-input-34-9754fb560d23>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['theta']+=90
#          x     y       phi        vx        vy         r     omega      theta  \
# 2506 -2.45 -4.35  0.268109 -2.051407  1.160247  4.992494 -0.472065 -29.388992
# 2507 -2.45 -4.25  0.557698 -1.817677  1.042084  4.905609 -0.427103 -29.962179
# 2606 -2.35 -4.35  0.579754 -2.010977  1.094703  4.944189 -0.463093 -28.379268
# 2607 -2.35 -4.25  0.611725 -1.555137  0.849581  4.856439 -0.364886 -28.940022
# 2608 -2.35 -4.15  0.629474 -1.451230  0.845739  4.769172 -0.352169 -29.521345
# ...    ...   ...       ...       ...       ...       ...       ...        ...
# 7306  2.35 -4.35  0.606558 -2.318590 -1.241007  4.944189 -0.531897  28.379249
# ...

# %%
delta = 0.1
df1['r-chunk'] = np.floor(df1['r']/delta)+1
df1 = df1[df1['y-ymin']<0]
df1
# Out:
#          x     y       phi        vx        vy         r     omega      theta  \
# 2506 -2.45 -4.35  0.268109 -2.051407  1.160247  4.992494 -0.472065 -29.388992
# 2507 -2.45 -4.25  0.557698 -1.817677  1.042084  4.905609 -0.427103 -29.962179
# 2606 -2.35 -4.35  0.579754 -2.010977  1.094703  4.944189 -0.463093 -28.379268
# 2607 -2.35 -4.25  0.611725 -1.555137  0.849581  4.856439 -0.364886 -28.940022
# 2608 -2.35 -4.15  0.629474 -1.451230  0.845739  4.769172 -0.352169 -29.521345
# ...    ...   ...       ...       ...       ...       ...       ...        ...
# 7306  2.35 -4.35  0.606558 -2.318590 -1.241007  4.944189 -0.531897  28.379249
# 7307  2.35 -4.25  0.584864 -1.825200 -0.997060  4.856439 -0.428246  28.940002
# 7308  2.35 -4.15  0.602008 -1.681213 -0.960820  4.769172 -0.406022  29.521383
# 7406  2.45 -4.35  0.280340 -2.292450 -1.283250  4.992494 -0.526223  29.389029
# 7407  2.45 -4.25  0.570666 -2.108473 -1.190147  4.905609 -0.493533  29.962159
#
# ...

# %%
for r in np.arange(1,np.max(df1['r-chunk'])+1,1):
    df2 = df1[df1['r-chunk']==r]
    df2 = df2.sort_values(by='theta')
    df2.head()
    plt.plot(df2['theta'],df2['omega'],marker='.')

    for x,y,text in zip(df2['theta'],df2['omega'],df2['r']):
        text = "{:.3f}".format(text)
        plt.annotate(text, # this is the text
                 (x,y), # these are the coordinates to position the label
                #  textcoords="offset points", # how to position the text
                #  xytext=(0,10), # distance from text to points (x,y)
                #  ha='center'# horizontal alignment can be left, right or center
                     )

    plt.xlabel('Theta')
    plt.ylabel('Omega')
    plt.title(f'chunk={r}')
    plt.show()

# %%
df2
# Out:
#          x     y       phi        vx        vy         r     omega      theta  \
# 2507 -2.45 -4.25  0.557698 -1.817677  1.042084  4.905609 -0.427103 -29.962179
# 2506 -2.45 -4.35  0.268109 -2.051407  1.160247  4.992494 -0.472065 -29.388992
# 2606 -2.35 -4.35  0.579754 -2.010977  1.094703  4.944189 -0.463093 -28.379268
# 2705 -2.25 -4.45  0.352888 -2.097330  1.058775  4.986482 -0.471159 -26.821969
# 2805 -2.15 -4.45  0.558980 -2.137207  1.032005  4.942166 -0.480220 -25.787322
# 2904 -2.05 -4.55  0.324124 -2.118110  0.952695  4.990491 -0.465385 -24.253915
# 3004 -1.95 -4.55  0.549924 -2.141880  0.923639  4.950253 -0.471196 -23.198584
# 3104 -1.85 -4.55  0.611152 -1.990593  0.796357  4.911721 -0.436496 -22.126351
# 3203 -1.75 -4.65  0.525786 -2.192040  0.832378  4.968400 -0.471932 -20.623540
# 3303 -1.65 -4.65  0.562431 -2.186047  0.761759  4.934065 -0.469173 -19.536639
# 3403 -1.55 -4.65  0.608297 -1.929287  0.647946  4.901530 -0.415213 -18.434956
# ...

# %%
values_to_match = [-4.25, -3.25, -2.25, -1.25, -0.25, 0.25, 1.25, 2.25, 3.25, 4.25]
df3 = df[df['x'].isin(values_to_match)]
df3 = df3[df3['y']<0]
df3
# Out:
#          x     y       phi        vx        vy         r     omega  \
# 724  -4.25 -2.55  0.592858 -1.044742  1.758003  4.956309 -0.412604
# 725  -4.25 -2.45  0.555268 -0.933776  1.669870  4.905609 -0.389973
# 726  -4.25 -2.35  0.601258 -0.795638  1.475153  4.856439 -0.345099
# 727  -4.25 -2.25  0.600502 -0.728152  1.461633  4.808846 -0.339472
# 728  -4.25 -2.15  0.601295 -0.663244  1.436823  4.762877 -0.332046
# ...    ...   ...       ...       ...       ...       ...       ...
# 9245  4.25 -0.45  0.603400  1.977517 -0.988924  4.273757 -0.181388
# 9246  4.25 -0.35  0.558606  3.142263 -0.751041  4.264387 -0.115047
# 9247  4.25 -0.25  0.529164  4.869677 -0.456480  4.257347 -0.039869
# 9248  4.25 -0.15  0.067129  5.305780 -0.317823  4.252646 -0.030682
# 9249  4.25 -0.05  0.000000  0.000000  0.000000  4.250294  0.000000
#
#            theta    vtheta    y-ymin      ymax
# 724  -149.036235 -2.044991 -2.550000  0.000000
# 725  -150.037822 -1.913055 -2.450000  0.000000
# ...

# %%
sns.lineplot(data=df3, x = df3['vx'],y = df3['y-ymin'],hue=df3['x'],legend=values_to_match,palette='coolwarm')
plt.xlim()
# Out:
# (-2.9816636499999998, 10.142670650000001)

# %%
df2
# Out:
#          x     y       phi        vx        vy         r     omega      theta  \
# 2507 -2.45 -4.25  0.557698 -1.817677  1.042084  4.905609 -0.427103 -29.962179
# 2506 -2.45 -4.35  0.268109 -2.051407  1.160247  4.992494 -0.472065 -29.388992
# 2606 -2.35 -4.35  0.579754 -2.010977  1.094703  4.944189 -0.463093 -28.379268
# 2705 -2.25 -4.45  0.352888 -2.097330  1.058775  4.986482 -0.471159 -26.821969
# 2805 -2.15 -4.45  0.558980 -2.137207  1.032005  4.942166 -0.480220 -25.787322
# 2904 -2.05 -4.55  0.324124 -2.118110  0.952695  4.990491 -0.465385 -24.253915
# 3004 -1.95 -4.55  0.549924 -2.141880  0.923639  4.950253 -0.471196 -23.198584
# 3104 -1.85 -4.55  0.611152 -1.990593  0.796357  4.911721 -0.436496 -22.126351
# 3203 -1.75 -4.65  0.525786 -2.192040  0.832378  4.968400 -0.471932 -20.623540
# 3303 -1.65 -4.65  0.562431 -2.186047  0.761759  4.934065 -0.469173 -19.536639
# 3403 -1.55 -4.65  0.608297 -1.929287  0.647946  4.901530 -0.415213 -18.434956
# ...

# %%
for theta in [-30,-20,-10,0,10,20,30]:
    df2 = df1.loc[(df1['theta']>theta-1) & (df1['theta']<theta+1)]
    df2 = df2.sort_values(by='r')
    plt.plot(df2['r'],df2['omega'],marker='.')

    for x,y,text in zip(df2['r'],df2['omega'],df2['y-ymin']):
        text = "{:.2f}".format(text)
        plt.annotate(text, # this is the text
                 (x,y), # these are the coordinates to position the label
                #  textcoords="offset points", # how to position the text
                #  xytext=(0,10), # distance from text to points (x,y)
                #  ha='center'# horizontal alignment can be left, right or center
                     )
    print(np.asarray(df2['y-ymin']))
    plt.title(theta)
    plt.xlabel('r')
    plt.ylabel('omega')
    plt.show()
# Out:
# [-1.65 -1.85 -2.05 -2.25 -2.35 -2.55 -2.75 -2.95 -3.05 -3.15 -3.25 -3.45
#  -3.65 -3.75 -3.85 -3.95 -4.05 -4.15 -4.25 -4.35]
# [-0.030782 -1.55     -1.75     -1.85     -2.05     -2.15     -2.25
#  -2.35     -2.45     -2.55     -2.65     -2.75     -2.75     -2.85
#  -2.95     -3.05     -3.15     -3.25     -3.35     -3.45     -3.55
#  -3.55     -3.65     -3.75     -3.85     -3.85     -3.95     -4.05
#  -4.05     -4.15     -4.15     -4.25     -4.35     -4.35     -4.45
#  -4.45     -4.55     -4.65     -4.65    ]
# [-0.033292 -1.55     -1.85     -1.95     -2.05     -2.15     -2.35
#  -2.45     -2.55     -2.65     -2.75     -2.85     -2.95     -3.05
#  -3.15     -3.25     -3.35     -3.35     -3.45     -3.45     -3.55
#  -3.65     -3.75     -3.85     -3.95     -3.95     -4.05     -4.05
#  -4.15     -4.25     -4.35     -4.45     -4.45     -4.55     -4.55
#  -4.65     -4.65     -4.75     -4.85    ]
# [-2.95 -2.95 -3.05 -3.05 -3.15 -3.15 -3.25 -3.25 -3.35 -3.35 -3.45 -3.45
# ...

# %% [markdown]
# ## Curve fitting for
#  - Omega vs r
#  - vx vs y
#  - vy vs y

# %%
df = pd.read_csv('avv0-1.dat',header=None,sep='\s')
df.columns = ['x','y','phi','vx','vy','r','omega','theta','vtheta','y-ymin','ymax']
df['theta']*=180/np.pi
df = df[df['r']<=5]
df
# Out:
# <ipython-input-2-66d44ed07156>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('avv0-1.dat',header=None,sep='\s')
#          x     y       phi        vx        vy         r     omega  \
# 43   -4.95 -0.65  0.238448 -0.234851  2.598540  4.992494 -0.522184
# 44   -4.95 -0.55  0.236605  0.092134  1.765765  4.980462 -0.350327
# 45   -4.95 -0.45  0.070629  0.349595  0.814089  4.970412 -0.156747
# 46   -4.95 -0.35  0.000547  0.055994  0.077238  4.962358 -0.014730
# 47   -4.95 -0.25  0.000000  0.000000  0.000000  4.956309  0.000000
# ...    ...   ...       ...       ...       ...       ...       ...
# 9952  4.95  0.25  0.000000  0.000000  0.000000  4.956309  0.000000
# 9953  4.95  0.35  0.000000  0.000000  0.000000  4.962358  0.000000
# ...

# %%
df1 = df.loc[(df['theta']>-120) & (df['theta']<-60)]
df1['theta']+=90
df1
# Out:
# <ipython-input-3-c79abba64af2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['theta']+=90
#          x     y       phi        vx        vy         r     omega      theta  \
# 2506 -2.45 -4.35  0.263452 -6.250855  3.523915  4.992494 -1.437304 -29.388992
# 2507 -2.45 -4.25  0.568721 -5.501305  3.178370  4.905609 -1.295140 -29.962179
# 2592 -2.45  4.25  0.000000  0.000000  0.000000  4.905609 -0.000000  29.962159
# 2593 -2.45  4.35  0.000000  0.000000  0.000000  4.992494 -0.000000  29.389029
# 2606 -2.35 -4.35  0.576066 -6.269505  3.436475  4.944189 -1.446024 -28.379268
# ...    ...   ...       ...       ...       ...       ...       ...        ...
# 7306  2.35 -4.35  0.574421 -7.372490 -4.003080  4.944189 -1.696771  28.379249
# ...

# %%
df2 = df1.sort_values(by='r')
df2 = df2[df2['y-ymin']<=0]
plt.plot(df2['r'],np.abs(df2['omega']),marker='.')
plt.xlabel('r')
plt.ylabel('omega')
plt.title(r'$\omega$ vs r for -30<$\theta$<30')
# Out:
# Text(0.5, 1.0, '$\\omega$ vs r for -30<$\\theta$<30')

# %%
# plt.semilogx(df2['r'],np.abs(df2['omega']),marker='.')
# plt.xlabel('r')
# plt.ylabel('omega')

# %%
def fun(r,a,b,c):
    return a - b*np.exp(-c*r)

# df3 = df2.loc[df2['r']<4.5]
parameters, covariance = curve_fit(fun, df2['r'][:-4], np.abs(df2['omega'][:-4]))

fit_a,fit_b,fit_c=parameters
y = fun(df2['r'][:-4],fit_a,fit_b,fit_c)
plt.plot(df2['r'][:-4],np.abs(df2['omega'][:-4]),marker='.')
plt.plot(df2['r'][:-4],y)
plt.xlabel('r')
plt.ylabel('omega')
print('R2 = ', r2_score(np.abs(df2['omega'][:-4]),y))
print(fit_a,fit_b,fit_c)
# Out:
# R2 =  0.7593466947027191
# 1.134439886013966 19.494985358566538 1.9678917384396886

# %%
df3 = df2.loc[df2['r']<4.5]
parameters, covariance = curve_fit(fun, df3['r'], np.abs(df3['omega']))

fit_a,fit_b,fit_c=np.round(parameters,3)
y = fun(df3['r'],fit_a,fit_b,fit_c)
plt.plot(df3['r'],np.abs(df3['omega']),marker='.')
plt.plot(df3['r'],y)
plt.xlabel('r')
plt.ylabel('omega')
print('R2 = ', r2_score(np.abs(df3['omega']),y))
print(fit_a,fit_b,fit_c)
plt.title(r'$\omega$ vs r for -30<$\theta$<30')
plt.legend(['Data',f'{fit_a}-{fit_b}exp(-{fit_c}r)'])
# Out:
# R2 =  0.9656217183348921
# 1.081 65.623 2.713

# %%
delta = 0.1
df3['rchunk'] = np.floor(df3['r']/delta)+1
chunked_omega = df3.groupby('rchunk')['omega'].mean()
plt.plot(np.arange(1.5,4.5,0.1), np.abs(np.asarray(chunked_omega)),marker='.')
plt.plot(df3['r'],y)
plt.ylabel('omega')
plt.xlabel('r')
plt.title(r'$\omega$ vs r (bins of size 0.1)')
plt.legend(['Data',f'{fit_a}-{fit_b}exp(-{fit_c}r)'])
# Out:
# <ipython-input-14-0a50ff7f5d38>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['rchunk'] = np.floor(df3['r']/delta)+1

# %%
values_to_match = [-4.25, -3.25, -2.25, -1.25, -0.25, 0.25, 1.25, 2.25, 3.25, 4.25]
df3 = df[df['x'].isin(values_to_match)]
df3 = df3[(df3['y']<df3['ymax'])]
sns.lineplot(data=df3, x = df3['vx'],y = df3['y-ymin'],hue=df3['x'],legend=values_to_match,palette='coolwarm')
plt.title(r'$y-y_{min}$ vs $v_{x}$')
plt.show()

# %%
values_to_match = [-4.25, -3.25, -2.25, -1.25, -0.25, 0.25, 1.25, 2.25, 3.25, 4.25]
df3 = df[df['x'].isin(values_to_match)]
df3 = df3[(df3['y']<df3['ymax']) & (df3['y-ymin']>=0)]
sns.lineplot(data=df3, x = df3['vx'],y = df3['y-ymin'],hue=df3['x'],legend=values_to_match,palette='coolwarm')
plt.title(r'$y-y_{min}$ vs $v_{x}$')
plt.show()
# sns.lineplot(data=df3, x = df3['vy'],y = df3['y-ymin'],hue=df3['x'],legend=values_to_match,palette='coolwarm')

# %%
#for fitting vx
def fun2(y,a,b):
    return a*y*(1-np.exp(-b*y))

# %%
inv_gamma_dot = []
a_values = []
b_values = []

# %%
xcoord = -4.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=-4.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-21-f72148d5e45d>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-21-f72148d5e45d>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.12220872] R2= 0.8684136207745101
# 16.007 1.18 R2= 0.9965259631581983

# %%
xcoord = -3.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=-3.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-22-e64e98d284b5>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-22-e64e98d284b5>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.07985744] R2= 0.9098585795070917
# 17.97 1.64 R2= 0.9989803640522896

# %%
xcoord = -2.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=-2.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-23-4d873d09591c>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-23-4d873d09591c>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.0729324] R2= 0.9277485866256558
# 16.942 2.017 R2= 0.9990508131190935

# %%
xcoord = -1.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=-1.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-24-397ce4aa7e5c>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-24-397ce4aa7e5c>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06913372] R2= 0.9563884802429123
# 16.258 2.393 R2= 0.9994139529125993

# %%
xcoord = -0.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=-0.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-25-7dc905136363>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-25-7dc905136363>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06563432] R2= 0.9648078198246173
# 16.671 2.667 R2= 0.9989410587402376

# %%
xcoord = 0.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=0.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-26-94d08b6e3721>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-26-94d08b6e3721>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06552758] R2= 0.9656148880385388
# 16.592 2.735 R2= 0.9991935462669007

# %%
xcoord = 1.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=1.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-27-089b78159d87>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-27-089b78159d87>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06679421] R2= 0.9534056925023909
# 16.877 2.325 R2= 0.9992744934266784

# %%
xcoord = 2.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=2.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

inv_gamma_dot.append(m)
a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-28-63d00558b782>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-28-63d00558b782>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06519066] R2= 0.9282112113012825
# 18.838 1.873 R2= 0.9991195086156572

# %%
xcoord = 3.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
inv_gamma_dot.append(m)

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.title(r'$y-y_{min}$ vs $v_{x}$ at x=3.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-29-de9444b57033>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-29-de9444b57033>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06552135] R2= 0.9155589613240611
# 20.991 1.625 R2= 0.9990821577888708

# %%
xcoord = 4.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
inv_gamma_dot.append(m)

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

par,cov = curve_fit(fun2,df4['y-ymin'],df4['vx'])
a,b=np.round(par,3)
plt.plot(df4['y-ymin'],fun2(df4['y-ymin'],a,b))
plt.title(r'$y-y_{min}$ vs $v_{x}$ at x=4.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-{b}(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-30-59386fe1d981>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-30-59386fe1d981>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.06584238] R2= 0.8518175300219731
# 25.19 1.893 R2= 0.9979797403978652

# %%
gamma_dot = 1/np.array(inv_gamma_dot)
print(gamma_dot)
delta0 = 5*(0.5/gamma_dot)**0.5
print(delta0)
# Out:
# [[ 8.1827222 ]
#  [12.52231417]
#  [13.71132772]
#  [14.46472142]
#  [15.23593201]
#  [15.26075074]
#  [14.97135772]
#  [15.33962026]
#  [15.26220135]
#  [15.18778612]]
# [[1.2359648 ]
#  [0.99910863]
#  [0.95480625]
#  [0.92960825]
#  [0.90577534]
#  [0.90503851]
#  [0.91374374]
#  [0.90270885]
#  [0.90499549]
#  [0.90720988]]
# 1.190955

# %%
plt.plot(values_to_match,gamma_dot,marker='o')
plt.xlabel('x')
plt.ylabel(r'$\dot{\gamma}$')
plt.title(r'$\dot{\gamma}$ vs x')
plt.show()
plt.plot(values_to_match,a_values,marker='o')
plt.xlabel('x')
plt.ylabel('a')
plt.title('a vs x')
plt.show()
plt.plot(values_to_match,b_values,marker='o')
plt.xlabel('x')
plt.ylabel('b')
plt.title('b vs x')
# Out:
# Text(0.5, 1.0, 'b vs x')

# %%
np.mean(b_values[1:-1])
# Out:
# 2.159375

# %%
xcoord = 2.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
inv_gamma_dot.append(m)

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

def fun3(y,a):
    return a*y*(1-np.exp(-0.8603*y))
par,cov = curve_fit(fun3,df4['y-ymin'],df4['vx'])
a=np.round(par,3)
plt.plot(df4['y-ymin'],fun3(df4['y-ymin'],a))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=2.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-0.8603(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-110-e1ed1fd47ed7>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-110-e1ed1fd47ed7>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.15437829] R2= 0.8210376890981224
# [12.525] 0.417 R2= 0.5714469249622626

# %%
xcoord = 3.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
inv_gamma_dot.append(m)

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

def fun3(y,a):
    return a*y*(1-np.exp(-0.8603*y))
par,cov = curve_fit(fun3,df4['y-ymin'],df4['vx'])
a=np.round(par,3)
plt.plot(df4['y-ymin'],fun3(df4['y-ymin'],a))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=3.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-0.8603(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-111-c3bbabbc34b4>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-111-c3bbabbc34b4>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.1569673] R2= 0.7081272339781051
# [13.47] 0.417 R2= 0.5338041721975031

# %%
xcoord = 4.25
df4 = df3[df3['x']==xcoord]
df4 = df4[df4['y-ymin']>=0]
df_line = df4

vx = df_line['vx'][:,np.newaxis]
m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
inv_gamma_dot.append(m)

print(m,'R2=',r2_score(df_line['y-ymin'],m*df_line['vx']))
plt.plot(df4['y-ymin'],df4['vx'],marker='o')
plt.plot(df_line['y-ymin'],1/m*df_line['y-ymin'])

def fun3(y,a):
    return a*y*(1-np.exp(-0.8603*y))
par,cov = curve_fit(fun3,df4['y-ymin'],df4['vx'])
a=np.round(par,3)
plt.plot(df4['y-ymin'],fun3(df4['y-ymin'],a))
plt.xlabel('y-ymin')
plt.ylabel('vx')
plt.title(r'$v_{x}$  vs $y-y_{min}$ at x=4.25')
plt.legend(['Data',f'vx={np.round(1/m,3)}(y-ymin)',f'vx={a}(y-ymin)(1-exp(-0.8603(y-ymin)))'])
print(a,b,'R2=',r2_score(df4['vx'],fun2(df4['y-ymin'],a,b)))

a_values.append(a)
b_values.append(b)
# Out:
# <ipython-input-112-c1e246aa01b3>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   vx = df_line['vx'][:,np.newaxis]
# <ipython-input-112-c1e246aa01b3>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,_,_,_ = np.linalg.lstsq(vx,df_line['y-ymin'])
# [0.15365881] R2= 0.6897329219126631
# [17.475] 0.417 R2= 0.5638555089254418

# %%
a_values.pop(7)
b_values.pop(7)
plt.plot(values_to_match,gamma_dot,marker='o')
plt.xlabel('x')
plt.ylabel(r'$\dot{\gamma}$')
plt.title(r'$\dot{\gamma}$ vs x')
plt.show()
plt.plot(values_to_match,a_values,marker='o')
plt.xlabel('x')
plt.ylabel('a')
plt.title('a vs x')
plt.show()
# plt.plot(values_to_match,b_values,marker='o')
# plt.xlabel('x')
# plt.ylabel('b')
# plt.title('b vs x')
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# Text(0.5, 1.0, 'b vs x')

# %%
sns.lineplot(data=df3, x = df3['vy'],y = df3['x']*(df3['ymax']-df3['y'])/(df3['y-ymin']-df3['y']+df3['ymax']),hue=df3['x'],legend=values_to_match,palette='coolwarm')
plt.ylabel('x(y-ymin)/delta')
# Out:
# Text(0, 0.5, 'x(y-ymin)/delta')

# %%
sns.lineplot(data=df3, x = np.abs(df3['vy']),y = df3['x']*df3['y-ymin']/(df3['y-ymin']-df3['y']+df3['ymax']),hue=df3['x'],legend=values_to_match,palette='coolwarm')
plt.ylabel('x(y-ymin)/delta')
plt.xlabel('abs(vy)')
# Out:
# Text(0.5, 0, 'abs(vy)')
